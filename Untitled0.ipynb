# %% [markdown]
# <a href="https://colab.research.google.com/github/Chakkis15/15-Chakkis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#โปรแกรมจัดการเวลาเล่นเกม
str(input('ชื่อไรครับ'))
str(input("จะทำอะไรก่อนเล่นเกมครับ"))
x = int(input("ถ้างานเสร็จแล้วให้กด1ครับ"))
if  x >= 1:
 print("งานเสร็จแล้วครับ")
 m = int(input("กำหนดเวลาเล่นเกม(นาที)"))
 print("จับเวลาถอยหลัง", m)
 for m in range(m, 0, -1):
  print("นาทีที่เหลือ")
 for _ in range(60):
  time.sleep(1)
  print("หมดเวลา")
# Out:
# ชื่อไรครับbas
# จะทำอะไรก่อนเล่นเกมครับ123
# ถ้างานเสร็จแล้วให้กด1ครับ1
# งานเสร็จแล้วครับ
# กำหนดเวลาเล่นเกม(นาที)20
# จับเวลาถอยหลัง 20
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# นาทีที่เหลือ
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4074792251.py in <cell line: 0>()
#      10   print("นาทีที่เหลือ")
#      11  for _ in range(60):
# ---> 12   time.sleep(1)
#      13   print("หมดเวลา")
#
# NameError: name 'time' is not defined
