# %% [markdown]
# <a href="https://colab.research.google.com/github/Chakkis15/15-Chakkis/blob/main/mid_(%E0%B9%80%E0%B8%A5%E0%B8%82%E0%B8%97%E0%B8%B5%E0%B9%8815)_Bas_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#โปรมแกรมอัตราการเต้นของหัวใจ
input("ชื่อไรครับ")
print("ยินดีต้อนรับสู่โปรแกรมบอกความปกติของหัวใจ")

x = int(input("ระบุHeart rate = "))
if x > 100:
 print("หัวใจเต้นเร็วเกินไป")
if x <= 100:
  print("หัวใจเต้นปกติ")
# Out:
# ชื่อไรครับbas
# ยินดีต้อนรับสู่โปรแกรมบอกความปกติของหัวใจ
# ระบุHeart rate = 120
# หัวใจเต้นเร็วเกินไป
